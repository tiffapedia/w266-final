# %%
import json
import emoji
import re
import nltk
import numpy as np
import tweets_processor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from collections import defaultdict
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

# %%
# parsing json file containing tweets
with open('tweets.json') as f_tweets:
    json_tweets = json.load(f_tweets)
#print(json_tweets[1]['text'])

tweets_text = [] # should we change this to numpy
tweets_place = []
for tweet in json_tweets:
    if (tweet['user']['geo_enabled'] == True):
        tweets_text.append(tweet['text'])
        tweets_place.append(tweet['place']['full_name'])

#print(tweets_text[1])
#print(len(tweets_text))
#print(len(tweets_place))

# %%
tweets_text, tweets_place = tweets_processor.get_tweets_from_csv()

# %%
s = 'test the 🤔 🙈 emojis, in 😌 here 💕👭'
s = ''.join(c for c in s if c not in emoji.UNICODE_EMOJI)
print(s)
# Out:
# test the   emojis, in  here

# %%
# vectorizing the text
## ????Add more custom parsing using nltk
#1. change to lower case
#2. stemming
#3. lemma
#4. canonicalize
#5. Remove urls
#6.remove emojis

def stem(match):
 # instantiate the PotterStemmer
 stemmer = PorterStemmer()
 # stem the word matched in the regex
 ts = stemmer.stem(match.group(1))
 return ts

def preprocessor(text):
 # convert to lower case
 text = text.lower()
 # remove urls
 text = re.sub(r'http\S+', '', text)
 #print(text)
 # remove stop words and emojis
 stop = set(stopwords.words('english'))
 text = ' '.join(word for word in nltk.word_tokenize(text) if word not in stop and word not in emoji.UNICODE_EMOJI)
 #print(text)
 # remove special characters and numbers
 text = re.sub(r'\W+', ' ', text)
 #s = re.sub('(_|\(|\))','',s)
 # removing all digits ????????????????? think about this
 text = re.sub(r'(\d+)', '', text)
 # remove emoji
 #text = ''.join(word for word in text if word not in emoji.UNICODE_EMOJI)
 # perform stemming on words
 #s = re.sub(r'(\b\w+\b)',stem,s)
 # remove two letter words
 text = re.sub(r'\b[a-z][a-z]\b','',text)
 # remove single letter 
 text = re.sub(r'\b[a-z]\b','',text)
 # remove underscores
 text = re.sub(r'_','',text)
 
 #print(text)
 return text

def tokenizer(text):
 tokens = nltk.word_tokenize(text)
 return tokens
 
#vectorizer = TfidfVectorizer(preprocessor = preprocessor, tokenizer=tokenizer)
# using bigrams
vectorizer = TfidfVectorizer(preprocessor = preprocessor, tokenizer=tokenizer,ngram_range=(2,2))
tweets_vectorized = vectorizer.fit_transform(tweets_text)

# length of total vocabulary
#print(len(vectorizer.vocabulary_))
print(tweets_vectorized.shape)


# count vectorizer
#count_vectorizer = CountVectorizer(preprocessor = preprocessor, tokenizer=tokenizer)
#using bigrams
count_vectorizer = CountVectorizer(preprocessor = preprocessor, tokenizer=tokenizer,ngram_range=(2,2))
tweets_count_vectorized = count_vectorizer.fit_transform(tweets_text)

# length of total vocabulary
print(count_vectorizer.vocabulary_)
print(count_vectorizer.get_feature_names())
#print(tweets_vectorized.shape)
# Out:
# (10001, 62407)
# {'like something': 31054, 'something twit': 49677, 'twit lil': 57029, 'lil pumpkin': 31209, 'pumpkin pops': 42986, 'future wife': 20000, 'wife better': 60262, 'better take': 5072, 'take country': 52670, 'wait denzel': 58439, 'let rest': 30332, 'rest get': 44924, 'get completely': 20414, 'completely healthy': 10309, 'healthy need': 24736, 'need bills': 36442, 'bills peterman': 5301, 'peterman starting': 40623, 'thank mailing': 53709, 'mailing bose': 33021, 'bose speaker': 6121, 'speaker great': 50110, 'great night': 22540, 'night sleep': 37436, 'sleep sleptoogoodmaybe': 49039, 'sleptoogoodmaybe lol': 49062, 'amazing custome': 1387, 'custome inside': 12046, 'happy halloween': 24129, 'drag elphaba': 14411, 'elphaba mess': 15390, 'mess wicked': 34407, 'wicked defygravity': 60252, 'thanks know': 53822, 'know thinks': 29185, 'thinks mom': 54359, 'mom time': 35188, 'eric key': 15945, 'key katie': 28560, 'katie house': 28350, 'ever wanted': 16335, 'wanted host': 58911, 'host show': 25991, 'show stage': 48430, 'stage weekly': 50636, 'weekly opportunity': 59683, 'opportunity email': 39007, 'email info': 15443, 'info cavern': 26971, 'cavern bar': 8213, 'true really': 56476, 'really gained': 43973, 'gained following': 20023, 'following school': 18773, 'school think': 46748, 'think concern': 54175, 'concern many': 10379, 'many people': 33549, 'people buy': 40180, 'buy tools': 7166, 'tools learn': 55780, 'learn skills': 29914, 'skills want': 48960, 'want building': 58746, 'building following': 6901, 'following getting': 18766, 'getting clients': 20786, 'clients even': 9517, 'even big': 16085, 'big ones': 5180, 'start sentence': 50777, 'sentence sir': 47572, 'toonerville deli': 55785, 'deli louisville': 13228, 'perfect window': 40443, 'window looniness': 60391, 'looniness right': 32143, 'right bunch': 45201, 'bunch must': 6968, 'must belong': 36027, 'belong insanity': 4782, 'insanity club': 27064, 'club alice': 9614, 'alice jones': 904, 'jones belongs': 28135, 'blessed bulldogs': 5679, 'ribs looking': 45098, 'looking great': 32087, 'great stop': 22574, 'stop today': 51398, 'today dine': 55235, 'dine carry': 13756, 'carry countryside': 7963, 'countryside grill': 11385, 'gon painted': 21694, 'painted like': 39451, 'like joke': 30915, 'buckle trump': 6840, 'trump stupid': 56602, 'stupid tweet': 51855, 'tweet stand': 56978, 'stand ground': 50661, 'ground please': 22721, 'please everyone': 41456, 'everyone wondering': 16544, 'wondering speak': 60829, 'speak finally': 50094, 'finally did': 18029, 'did trump': 13641, 'trump insane': 56557, 'insane think': 27062, 'think respect': 54276, 'respect amp': 44867, 'amp honor': 1752, 'honor know': 25784, 'know creep': 29025, 'creep please': 11732, 'please smart': 41496, 'smart crazy': 49163, 'crazy amp': 11597, 'amp know': 1771, 'know kiss': 29089, 'forget sign': 18955, 'sign december': 48619, 'december sat': 13017, 'sat deadline': 46226, 'deadline november': 12887, 'watched obedience': 59149, 'obedience crufts': 38018, 'crufts many': 11864, 'many years': 33577, 'years ago': 61972, 'ago loved': 681, 'loved seeing': 32599, 'seeing dogs': 47251, 'dogs work': 14125, 'work many': 61014, 'many dogs': 33509, 'dogs obedience': 14122, 'obedience western': 38019, 'western part': 59983, 'fall favs': 17219, 'favs gorgeous': 17603, 'gorgeous oxidized': 22005, 'oxidized metal': 39357, 'metal statement': 34450, 'statement earrings': 50914, 'earrings ootd': 14997, 'ootd lotd': 38812, 'lotd fashion': 32302, 'fashion earrings': 17456, 'earrings jewels': 14995, 'jewels shop': 27761, 'know desperate': 29033, 'desperate liberal': 13497, 'liberal democrats': 30445, 'democrats people': 13318, 'people will': 40384, 'will not': 60309, 'not let': 37672, 'let destroy': 30274, 'destroy america': 13509, 'america trump': 1492, 'trump life': 56566, 'life patriots': 30606, 'patriots will': 39958, 'will storm': 60310, 'storm election': 51463, 'election polls': 15315, 'polls vote': 41721, 'vote november': 58291, 'november republican': 378 ...
# ['aaahhhhh breathe', 'aaf life', 'aag staff', 'aagf wearelakota', 'aaron maybe', 'aaron rodgers', 'aaronhunter happyhalloween', 'aaubasketball ballislife', 'abandon bigger', 'abc daycare', 'abc family', 'abc hounews', 'abc tree', 'abcdaycare sanantonio', 'abes highexpectations', 'abi amp', 'abilene supplychain', 'ability control', 'ability pipe', 'able build', 'able comprehend', 'able eat', 'able force', 'able get', 'able life', 'able manage', 'able play', 'able recognize', 'able release', 'able renovating', 'able reverse', 'able ride', 'able see', 'able serve', 'able sleep', 'able take', 'able understand', 'abort mission', 'aborted rate', 'aborting babies', 'abortions nationwide', 'abound together', 'about dude', 'about everything', 'about week', 'abroad many', 'abroad years', 'abruptly pains', 'abs boi', 'absence made', 'absence political', 'absence traded', 'absentee ballot', 'absentee ballots', 'absolute believer', 'absolute black', 'absolute heartbreaker', 'absolute opposite', 'absolutely absurd', 'absolutely agree', 'absolutely better', 'absolutely comparison', 'absolutely complaining', 'absolutely correct', 'absolutely crucial', 'absolutely deserved', 'absolutely disappointed', 'absolutely fyi', 'absolutely hate', 'absolutely nothing', 'absolutely off', 'absolutely refusing', 'absolutely waste', 'absorbed pig', 'abstractart contemporaryart', 'absurd none', 'absurd tirade', 'absurdity going', 'abt lots', 'abt rest', 'abundant time', 'abused gifts', 'abuser destroying', 'abusers startled', 'abusing black', 'abusive forceful', 'abusive lmao', 'abusive special', 'abut military', 'abv food', 'aca huh', 'aca pre', 'aca reps', 'acab construction', 'academic beginnings', 'academic paper', 'academic success', 'academic technology', 'academy indian', 'academy last', 'academy legal', 'academy newburgh', 'acb aphqf', 'acc problem', 'accelerator advisor', 'accept fact', 'accept truth', 'acceptable costume', 'acceptable light', 'acceptable listen', 'acceptable strange', 'acceptance notice', 'accepted blood', 'accepting money', 'access affordability', 'access amp', 'access healthcare', 'access internet', 'access large', 'access scary', 'accesscontrol usgatesupply', 'accessible many', 'accessories born', 'accessories everyone', 'accessories headphones', 'accessories literally', 'accessories phenomenal', 'accessories suspension', 'accessorize catwoman', 'accessory added', 'accident cleared', 'accident columbus', 'accident grandrapidstownship', 'accident hit', 'accident hollywood', 'accident irondequoit', 'accident killin', 'accident left', 'accident reported', 'accident right', 'accident seattle', 'accident spencerport', 'accident sunrise', 'accident three', 'accident two', 'accident universalcity', 'accident westmilwaukee', 'accidentally dried', 'accidentally letting', 'accidents good', 'accidents medical', 'accompanied little', 'accompany journey', 'accompanying neuroses', 'accomplish goal', 'accomplished could', 'accomplished helping', 'accomplished short', 'accomplished things', 'accomplishment wearebarrons', 'accomplishments months', 'according bible', 'according cnn', 'according new', 'according purpose', 'according students', 'according supposedly', 'accordingly freedom', 'account analyst', 'account bot', 'account catch', 'account evil', 'account fake', 'account flyers', 'account followed', 'account highly', 'account invlolves', 'account manager', 'account pack', 'account personal', 'account sales', 'account suspended', 'account unborn', 'accountability getting', 'accountable want', 'accountant shot', 'accountemps team', 'accounting ardmore', 'accounting baltimore', 'accounting bellingham', 'accounting hagerstown', 'accounting hiring', 'accounting job', 'accounting postfalls', 'accounting springfield', 'accounting westdesmoines', 'accounts giving', 'accounts message', 'accurate description', 'accurate mean', 'accurate period', 'accurate saves', 'accurate thing', 'accusations made', 'accused candace', 'accuser researching', 'accus ...

# %%
print(tweets_text[0], tweets_vectorized[1], vectorizer.get_feature_names()[1485], vectorizer.get_feature_names()[1452], vectorizer.get_feature_names()[2172], tweets_place[0])
vocab = vectorizer.get_feature_names()
place_word_score = defaultdict(lambda: defaultdict(lambda: 0.0))
word_place_score = defaultdict(lambda: defaultdict(lambda: 0.0))
word_score = dict()
for index, tweet in enumerate(tweets_vectorized):
    place = tweets_place[index]
    for word_index, score in zip(tweet.indices, tweet.data):
        word = vocab[word_index]
        existing_place = place_word_score.get(place, None)
        if existing_place is not None and existing_place.get(word, None) is not None:
            score = existing_place.get(word) + score
        # stores for each place what are all the words
        place_word_score[place][word] = score
        word_score_in_dict = word_score.get(word, None)
        # update the dict with the place and word only when there is no word in dict(word_score) with a score or if the score is greater for this place than the previous place
        # also update the word_score with new score
        if word_score_in_dict is None or word_score_in_dict < score:
            word_place_score[word] = {place:score}
            word_score[word] = score
print(word_place_score)
# Out:
# text   (0, 8924)	0.23670616541879838
#   (0, 14308)	0.3338910725889262
#   (0, 16218)	0.5699211122735731
#   (0, 8931)	0.39683969623087334
#   (0, 12274)	0.36238570578204915
#   (0, 11820)	0.4678372841311734 birthright billboard callin region
# defaultdict(<function <lambda> at 0x1a0adb4268>, {'text': {'houston': 1.5096996024737193}, 'like': {'new york': 15.095836912734516}, 'something': {'washington': 3.2822583079781436}, 'twit': {'cincinnati': 0.5699211122735731}, 'lil': {'nashville': 2.5809287064887294}, 'pumpkin': {'new york': 3.013139854249177}, 'pops': {'chicago': 1.388223801632021}, 'future': {'houston': 1.1479525407792108}, 'wife': {'new york': 1.6975818830703024}, 'better': {'new york': 5.721727709695995}, 'take': {'new york': 6.078621223203761}, 'country': {'new york': 2.4407310967190763}, 'wait': {'los angeles': 4.208722562979608}, 'denzel': {'chicago': 0.8565875695288604}, 'let': {'tampa': 5.0267190193799225}, 'rest': {'houston': 1.2645261484131152}, 'get': {'los angeles': 12.475096031701836}, 'completely': {'new york': 1.069723507087759}, 'healthy': {'new york': 1.4184373658647356}, 'need': {'houston': 7.997687605683696}, 'bills': {'new york': 1.2148803411970812}, 'peterman': {'minneapolis': 0.6168501571603956}, 'starting': {'nashville': 1.4754705305397908}, 'thank': {'houston': 8.159047971097328}, 'mailing': {'houston': 0.42995507027479407}, 'bose': {'houston': 0.41163789288065755}, 'speaker': {'houston': 0.3885609785398657}, 'great': {'new york': 5.367264330443923}, 'night': {'los angeles': 5.6799670572796}, 'sleep': {'washington': 1.644021425675191}, 'sleptoogoodmaybe': {'houston': 0.42995507027479407}, 'lol': {'houston': 11.153819125355128}, 'amazing': {'new york': 2.4453307638793875}, 'custome': {'houston': 0.7058387825378756}, 'inside': {'houston': 1.18152002254826}, 'happy': {'los angeles': 31.654259108322204}, 'halloween': {'los angeles': 39.60747950314646}, 'drag': {'houston': 0.8388952307076329}, 'elphaba': {'charlotte': 0.47006808910840914}, 'mess': {'tampa': 0.717019369160541}, 'wicked': {'charlotte': 0.47006808910840914}, 'defygravity': {'charlotte': 0.47006808910840914}, 'thanks': {'new york': 4.939269026974941}, 'know': {'new york': 11.813687002474799}, 'thinks': {'new york': 0.8190681768532418}, 'mom': {'houston': 2.6361992883459333}, 'time': {'new york': 7.8196084186357115}, 'eric': {'las vegas': 0.6045231402423787}, 'key': {'houston': 0.7848734614886794}, 'katie': {'phoenix': 0.7804263755129777}, 'house': {'new york': 4.369842689784101}, 'ever': {'charlotte': 3.1179551037369895}, 'wanted': {'los angeles': 1.994516443968422}, 'host': {'toronto': 0.3416432305281006}, 'show': {'los angeles': 3.4234082577922216}, 'stage': {'new york': 0.3649015051045056}, 'weekly': {'los angeles': 0.574026859006666}, 'opportunity': {'los angeles': 0.8244988803092683}, 'email': {'toronto': 0.9821446239500873}, 'info': {'new york': 1.2273123849629375}, 'cavern': {'toronto': 0.38622610501144317}, 'bar': {'los angeles': 1.1388182683808865}, 'true': {'tampa': 1.4689017715757933}, 'really': {'houston': 8.042287018939762}, 'gained': {'houston': 0.41795666333138665}, 'following': {'kansas city': 1.5800300590912384}, 'school': {'los angeles': 3.8899528428519785}, 'think': {'new york': 5.758099671245507}, 'concern': {'charlotte': 0.43409638756385976}, 'many': {'charlotte': 3.4078484725847313}, 'people': {'new york': 7.548443001223804}, 'buy': {'tampa': 1.6490177975418}, 'tools': {'chicago': 0.41675475042243737}, 'learn': {'new york': 1.245941981491331}, 'skills': {'seattle': 0.6543389056424962}, 'want': {'houston': 7.486809690372682}, 'building': {'new york': 1.7213595006340956}, 'getting': {'new york': 5.154590183928292}, 'clients': {'new york': 0.5684763040854892}, 'even': {'nashville': 3.3568757691271065}, 'big': {'nashville': 3.4982480268775387}, 'ones': {'los angeles': 1.3462814075881893}, 'start': {'new york': 2.039589724276452}, 'sentence': {'tampa': 0.6480307512749015}, 'sir': {'houston': 1.2597716279329798}, 'toonerville': {'cincinnati': 0.6048589610925789}, 'deli': {'cincinnati': 0.5790904339725595}, 'louisville': {'cincinnati': 1.860772793774554}, 'perfect': {'oklahoma city': 1.7996214725154394}, 'window': {'chicago': 0.9681974420720088}, 'looniness': {'ch ...

# %%
# splitting the data into train, dev, test
#train_data, train_labels = tweets_text[:700], tweets_place[:700] # ????see if we automatically split it proportinately irrespective of size 
#dev_data, dev_labels = tweets_text[700:901], tweets_place[700:901]
#test_data, test_labels = tweets_text[901:], tweets_place[901:]
print(tweets_text[1], tweets_vectorized[1], vectorizer.get_feature_names()[31054], vectorizer.get_feature_names()[1452], vectorizer.get_feature_names()[2172], tweets_place[1])

# using train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(tweets_vectorized, tweets_place, test_size=0.33, random_state=0)

#using count vectorized tweets
#train_data, test_data, train_labels, test_labels = train_test_split(tweets_count_vectorized, tweets_place, test_size=0.33, random_state=0)
# Out:
# When you like something on twit a lil pumpkin pops up🎃🙈   (0, 31054)	0.4548641685301028
#   (0, 49677)	0.4548641685301028
#   (0, 57029)	0.4548641685301028
#   (0, 31209)	0.4354858003208915
#   (0, 42986)	0.4354858003208915 america phonies amendment requires another cap cincinnati

# %%
train_data[0]
# Out:
# <1x62407 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
# training the model using logisticRegression with multinomial
####???? if there is a better library to use and a better classifier to use, should i svm, ridge classifier?

# Logistic Regression
lg = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial')
lg.fit(train_data, train_labels)

print("Accuracy on test set: {:.02%}".format(lg.score(test_data, test_labels)))
# print(lg.score(test_data, test_labels))

#Ridge Classifier
rc = RidgeClassifier()
rc.fit(train_data, train_labels)

pred = rc.predict(test_data)

print("Accuracy on test set: {:.02%}".format(rc.score(test_data, test_labels)))
#print(rc.score(test_data, test_labels))
#print(classification_report(test_labels, pred))
# Out:
# Accuracy on test set: 15.21%
# Accuracy on test set: 14.66%

# %%
# using naive bayes
nb = MultinomialNB()
nb.fit(train_data, train_labels)
y_pred = nb.predict(test_data)
acc = accuracy_score(test_labels, y_pred)
print("Accuracy on test set: {:.02%}".format(acc))
# Out:
# Accuracy on test set: 13.90%

# %%
# using MLP classifier
mlp = MLPClassifier(hidden_layer_sizes=(100, ),)
mlp.fit(train_data, train_labels)
y_pred = mlp.predict(test_data)
acc = accuracy_score(test_labels, y_pred)
print("Accuracy on test set: {:.02%}".format(acc))
# Out:
# Accuracy on test set: 13.39%
# /Users/divyagorantla/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
