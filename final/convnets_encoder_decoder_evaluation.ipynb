# %%
import mlflow
import keras
import numpy as np
import mlflow.keras
import importlib
import os
import pandas as pd
import tensorflow as tf
from keras.models import load_model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Lambda
from keras.layers import Embedding
from keras.layers import LSTM, RepeatVector
from sklearn.model_selection import train_test_split
from collections import Counter
from keras import backend as K
from sklearn.neighbors import NearestNeighbors
from keras.layers import Input
from scipy.optimize import fmin_l_bfgs_b
from keras.optimizers import Adam, Nadam, RMSprop, Adadelta
from keras.activations import softmax, relu, tanh
from keras.losses import categorical_crossentropy, logcosh, binary_crossentropy
from keras.initializers import Constant
from keras.models import Model
from keras.layers import TimeDistributed
from keras import objectives
from keras.layers import Conv1D, MaxPooling1D, UpSampling1D
from keras.layers import Dense, Dropout, Flatten
from scipy.spatial.distance import cdist
from keras.callbacks import ModelCheckpoint
from keras.layers import Cropping1D
from keras.layers import BatchNormalization
from nltk.translate.bleu_score import sentence_bleu,SmoothingFunction
# Out:
# Using TensorFlow backend.

# %%
# another way to process the csv data
df = pd.read_csv('../data/tweets_labelled_balanced.csv', nrows=300000)
df.dropna(inplace=True)
df.region = df.region.astype(int)
tweets_text = df.text.tolist()
tweets_regions = df.region.tolist()

# %%
# tokenize
# create the tokenizer at word level
t = Tokenizer(lower = True, filters ='')
t.fit_on_texts(tweets_text)

# %%
# get the vocab size
vocab = list(t.word_counts.keys())
vocab_size = len(t.word_counts) + 1
vocab_ids = list(t.word_index.values())
word_index = t.word_index

# %%
# convert the test tweets to sequence of id's
encoded_tweets = t.texts_to_sequences(tweets_text)#test_tweets

max_len = len(max(encoded_tweets, key=len))

# %%
# load trained model
model_dir_path = 'cnn_300k.h5'
model = load_model(model_dir_path)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 68)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 68, 100)      33632000    input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv1D)                  (None, 68, 128)      38528       embedding_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 68, 128)      512         conv1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv1D)                  (None, 68, 64)       24640       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 68, 64)       256         conv2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 68, 64)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4352)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 256)          1114368     flatten[0][0]
# __________________________________________________________________________________________________
# conv5 (Conv1D)                  (None, 68, 64)       12352       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 68, 64)       256         conv5[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 256)          65792       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv1D)                  (None, 68, 128)      24704       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           dense2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 68, 128)      512         conv6[0][0]
# __________________________________________________________________________________________________
# dense3 (Dense)                  (None, 256)          65792       dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 68, 128)      0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense4 (Dense)                  (None, 23)           5911        dense3[0][0]
# __________________________________________________________________________________________________
# dense5 (Dense)                  (None, 68, 336320)   43385280    dropout_4[0][0]
# ==================================================================================================
# Total params: 78,370,903
# Trainable params: 44,738,135
# Non-trainable params: 33,632,768
# __________________________________________________________________________________________________

# %%
# create dictionary of layers
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
layer_dict
# Out:
# {'batch_normalization_1': <keras.layers.normalization.BatchNormalization at 0x1a28377390>,
#  'batch_normalization_2': <keras.layers.normalization.BatchNormalization at 0x1a283776a0>,
#  'batch_normalization_3': <keras.layers.normalization.BatchNormalization at 0x1a28377d30>,
#  'batch_normalization_4': <keras.layers.normalization.BatchNormalization at 0x1a20c471d0>,
#  'conv1': <keras.layers.convolutional.Conv1D at 0x1a28377400>,
#  'conv2': <keras.layers.convolutional.Conv1D at 0x1a28377518>,
#  'conv5': <keras.layers.convolutional.Conv1D at 0x1a28377a58>,
#  'conv6': <keras.layers.convolutional.Conv1D at 0x1a28377e80>,
#  'dense1': <keras.layers.core.Dense at 0x1a283779e8>,
#  'dense2': <keras.layers.core.Dense at 0x1a28377d68>,
#  'dense3': <keras.layers.core.Dense at 0x1a20c472e8>,
#  'dense4': <keras.layers.core.Dense at 0x1a20c47470>,
#  'dense5': <keras.layers.core.Dense at 0x1a20c475c0>,
#  'dropout_1': <keras.layers.core.Dropout at 0x1a28377898>,
#  'dropout_2': <keras.layers.core.Dropout at 0x1a28377ba8>,
#  'dropout_3': <keras.layers.core.Dropout at 0x1a20c47198>,
#  'dropout_4': <keras.layers.core.Dropout at 0x1a20c47438>,
#  'embedding_1': <keras.layers.embeddings.Embedding at 0x1a28377358>,
#  'flatten': <keras.layers.core.Flatten at 0x1a283779b0>,
#  'input_1': <keras.engine.input_layer.InputLayer at 0x1a283772e8>}

# %%
# reverse word_index
reverse_word = dict((v,k) for k, v in word_index.items())

# %%
# get text from id's
def get_text(data, input_sequence_length):
    inner_string = []
    for i, id in enumerate(data):
        if i < input_sequence_length:
            if id != 0:
                inner_string.append(reverse_word[id])
        else:
            break
    text = ' '.join(inner_string)
    return text

# %%
# gradient ascent
def get_gradients(region_label):
    layer_output = layer_dict['dense4'].output
    # the target region to which we want the manupilation
    loss = K.mean(layer_output[:, region_label]) 
    # compute the gradient of the input text wrt to this loss
    grads = K.gradients(loss, model.layers[2].input)[0]
    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)
    # this function returns the loss and grads given the input picture
    iterate = K.function([model.layers[2].input], [loss, grads]) # passing embedding layer as input
    
    return iterate

# %%
def apply_gradient_ascent(text, region_label):
    step = 1
    gradients_iterator = get_gradients(region_label)
    for i in range(5):
        loss_value, grads_value = gradients_iterator([text])
        #print(loss_value, grads_value)
        if loss_value > 0.95 or loss_value <= 0.: 
            break
        text += grads_value * step
        
    return text

# %%
# get the embedding layer output for the input from model
get_embedding_layer_output = K.function([model.layers[0].input],
                                  [model.layers[1].output])

# %%
# get final dense layer output with input as the embedding 
get_final_dense_layer_output = K.function([model.layers[2].input],
                                  [layer_dict['dense5'].output])

# %%
# get the final dense layer output for the original input
get_dense_output = K.function([model.layers[0].input],
                                  [layer_dict['dense5'].output])

# %%
# get region probabilities for a tweet, used for getting class of translated tweet
get_region_probabilities = K.function([model.layers[0].input],
                                  [layer_dict['dense4'].output])

# %%
# passing data for translation
def translate_tweet(input_tweet, region_translate_to):
    #pass through the embedding layer, to the output
    emb_input = get_embedding_layer_output([np.array([input_tweet])])[0]
    # apply gradient ascent
    after_gradient_ascent = apply_gradient_ascent(emb_input, region_translate_to)
    # get final dense layer output
    output_text_from_traslator = get_final_dense_layer_output([after_gradient_ascent])[0]
    # get the id's with maximum probability for each word
    translated_output = np.argmax(output_text_from_traslator, axis=-1)
    translated_output =  np.squeeze(translated_output)
    
    return translated_output

# %%
# bleu score
def get_bleu_score(original_tweet, retranslated_tweet):
    reference = original_tweet.split()
    candidate = retranslated_tweet.split()
    cc = SmoothingFunction()
    score = sentence_bleu([reference], candidate, smoothing_function = cc.method4)
    return score

# %%
def get_tweet_region(text):
    #print(text)
    probabilities = get_region_probabilities([np.array([text])])
    region = np.argmax(probabilities, axis=-1)
    
    return region

# %%
# Run the model on the 130 tweets
text = open("test_tweets.txt").read()
test_tweets = eval(text)

# %%
# translating the 130 test tweets, we translate from it's original region to the next region in this list
region_ids = [3,  4,  5,  7, 10, 13, 14, 15, 18, 19, 20, 21, 22]
region_dict = {0: "albuquerque", 1: "billings", 2: "calgary", 3: "charlotte", 4: "chicago", 5: "cincinnati", 6: "denver", 
               7: "houston", 8: "kansas city", 9: "las vegas", 10: "los angeles", 11: "minneapolis", 12: "montreal", 
               13: "nashville", 14: "new york", 15: "oklahoma city", 16: "phoenix", 17: "pittsburgh", 18: "san francisco", 
               19: "seattle", 20: "tampa", 21: "toronto", 22: "washington"}

df_scores = pd.DataFrame(columns=['Source', 'Target', 'Decile', 'Original', 'Translation', 'Trans Region', 'Trans BLEU', 
                                  'Retranslation', 'Retrans Region', 'Retrans BLEU'])

trans_score = 0
retrans_score = 0

for i in range(len(region_ids)):
    source = region_ids[i]
    target = region_ids[i+1] if i+1 < len(region_ids) else region_ids[0]
    test_seq = t.texts_to_sequences(test_tweets[source])
    padded_tweets = pad_sequences(test_seq,padding='post',maxlen=max_len)
    print("ith region:",i)
    print("number of tweets:",len(padded_tweets))

    for x in range(len(padded_tweets)):
        print("xth tweet:",x)
        length = len(test_seq[x])
        original = padded_tweets[x]
        translation = translate_tweet(original, target)
        retranslation = translate_tweet(translation, source)
        original_sentence = get_text(original, length)
        translated_sentence = get_text(translation, length)
        retranslated_sentence = get_text(retranslation, length)
        trans_bleu = get_bleu_score(original_sentence, translated_sentence)
        retrans_bleu = get_bleu_score(original_sentence, retranslated_sentence)
        trans_region = int(get_tweet_region(translation)[0][0])
        retrans_region = int(get_tweet_region(retranslation)[0][0])
        trans_score += 1 if trans_region==target else 0
        retrans_score += 1 if retrans_region==source else 0
        
        #print(trans_region)
        print("before dataframe")
        df_scores.loc[10*i + x] = [region_dict[source], region_dict[target], x, original_sentence, translated_sentence, 
                            region_dict[trans_region], trans_bleu, retranslated_sentence, region_dict[retrans_region], 
                            retrans_bleu]
# Out:
# ith region: 0
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 1
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 2
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 3
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 4
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 5
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 6
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 7
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 8
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 9
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 10
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 11
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe
# ith region: 12
# number of tweets: 10
# xth tweet: 0
# before dataframe
# xth tweet: 1
# before dataframe
# xth tweet: 2
# before dataframe
# xth tweet: 3
# before dataframe
# xth tweet: 4
# before dataframe
# xth tweet: 5
# before dataframe
# xth tweet: 6
# before dataframe
# xth tweet: 7
# before dataframe
# xth tweet: 8
# before dataframe
# xth tweet: 9
# before dataframe

# %%
trans_score/130
# Out:
# 0.16923076923076924

# %%
retrans_score/130
# Out:
# 0.2

# %%
df_scores['Trans BLEU'].mean()
# Out:
# 0.042453034848165358

# %%
df_scores['Retrans BLEU'].mean()
# Out:
# 0.060408287369466497

# %%
df_scores
# Out:
#          Source      Target Decile  \
# 0     charlotte     chicago      0
# 1     charlotte     chicago      1
# 2     charlotte     chicago      2
# 3     charlotte     chicago      3
# 4     charlotte     chicago      4
# 5     charlotte     chicago      5
# 6     charlotte     chicago      6
# 7     charlotte     chicago      7
# 8     charlotte     chicago      8
# 9     charlotte     chicago      9
# 10      chicago  cincinnati      0
# 11      chicago  cincinnati      1
# 12      chicago  cincinnati      2
# 13      chicago  cincinnati      3
# 14      chicago  cincinnati      4
# 15      chicago  cincinnati      5
# 16      chicago  cincinnati      6
# 17      chicago  cincinnati      7
# 18      chicago  cincinnati      8
# 19      chicago  cincinnati      9
# 20   cincinnati     houston      0
# 21   cincinnati     houston      1
# 22   cincinnati     houston      2
# 23   cincinnati     houston      3
# 24   cincinnati     houston      4
# 25   cincinnati     houston      5
# 26   cincinnati     houston      6
# 27   cincinnati     houston      7
# 28   cincinnati     houston      8
# 29   cincinnati     houston      9
# ..          ...         ...    ...
# 100       tampa     toronto      0
# 101       tampa     toronto      1
# 102       tampa     toronto      2
# 103       tampa     toronto      3
# 104       tampa     toronto      4
# 105       tampa     toronto      5
# 106       tampa     toronto      6
# 107       tampa     toronto      7
# 108       tampa     toronto      8
# 109       tampa     toronto      9
# 110     toronto  washington      0
# 111     toronto  washington      1
# 112     toronto  washington      2
# 113     toronto  washington      3
# 114     toronto  washington      4
# 115     toronto  washington      5
# 116     toronto  washington      6
# 117     toronto  washington      7
# 118     toronto  washington      8
# 119     toronto  washington      9
# 120  washington   charlotte      0
# 121  washington   charlotte      1
# 122  washington   charlotte      2
# 123  washington   charlotte      3
# 124  washington   charlotte      4
# 125  washington   charlotte      5
# 126  washington   charlotte      6
# 127  washington   charlotte      7
# 128  washington   charlotte      8
# 129  washington   charlotte      9
#
#                                               Original  \
# 0                             not true. but i hear you
# 1    thursday isn’t coming fast enough i’m ready to...
# 2    awful first quarter again for the still can’t ...
# 3    compare trump manufacturing numbers to kindly ...
# 4    why you should train like a if you're a | - if...
# 5                         if only we had that espn cam
# 6            the comments on this unc g ucla feed 😂😂😂😂
# 7                             with the sc on our chest
# 8              ➡️ for the 44 yard tech 7 ii georgia 28
# 9    we're #hiring! read about our latest #job open...
# 10                 is all about show and nothing about
# 11   we are so thankful for everyone’s donations so...
# 12   well i would have never that! what was her fav...
# 13     temperature up -&gt; down -&gt; 7mph -&gt; 5mph
# 14   a hint in the book of love to only one person ...
# 15   at - drinking a vanilla porter by @ lake brewi...
# 16   i liked him, too. he just couldn't get right. ...
# 17   crazy as this still sits in my mind how i supp...
# 18   i’m a fan of the chicago version of board game...
# 19   can you recommend anyone for this #job in il? ...
# 20               made this for &amp; hope they like it
# 21   being than you are literally at when it comes ...
# 22     one taught me love taught me one taught me pain
# 23   i’m so thankful to have parents who are the gr...
# 24   does anyone else’s heart drop at the sound of ...
# 25   if only notre dame could figure out how to a c...
# 26   may we all experience this joy at the end. is ...
# 27   one could argue that no one brings more to a a...
# 28   interested in a #job in #indianapolis, in? thi...
# 29   big game. big implications. i'm picking #4 mic...
# ..                                                 ...
# 100                        &amp; and old is not enough
# 101  i just turned on fox and whose face do i see a...
# 102            yep, the democratic firing squad has as
# 103  sounds like a weird cookie handling issue. won...
# 104  leaving any doubt about how crooked everyone i...
# 105  evil democrats steal elections by encouraging ...
# 106  in florida on holiday from the uk was up most ...
# 107  want to work at kelly services? we're #hiring ...
# 108                 happy 90th birthday mickey mouse !
# 109  andrew gillum let’s bring this home! #florida ...
# 110            if you're wondering they are last video
# 111                    are we screwed on the over yet?
# 112  2018 beauty monthly all products are &amp; hav...
# 113  5 game winning streak for thanks to tom wilson...
# 114  we're #hiring! read about our latest #job open...
# 115  attended doug god space workshop at church and...
# 116  sabres should try and get from the whatever we...
# 117  school of public health alum kate presents fro...
# 118  enter the #goatblackfriday raffle for your cha...
# 119         new 🔥🔥 link in bio \r\n @ toronto, ontario
# 120
# 121  nope. just too fucked up. you need to read car...
# 122   adults jokes in that you totally missed as a kid
# 123  we are holding a #career event on in come meet...
# 124  donald the con is lying . neither russia or ch...
# 125  join the group team! see our latest #job openi...
# 126  be a part of a progressive organization dedica...
# 127  follett is improving the world by inspiring le...
# 128  can you recommend anyone for this #job in va? ...
# 129  want to work at virginia department of we're #...
#
#                                            Translation Trans Region  \
# 0                       polar up then studios cared va     new york
# 1    palace going how invaded toast strawberry chee...     new york
# 2    walked they freezing to gets per shoutout hood...      chicago
# 3    logan it it screens unnecessarily mailing stra...     new york
# 4    terminal out toronto, routes park terminal wil...      toronto
# 5    england india woken rode terminal metro strawb...     new york
# 6    what it you attack mueller harry terminal va feel     new york
# 7                        f. ontario never va harry ive     new york
# 8    go ontario harry gordon buena toast graffiti n...     new york
# 9    tour button cringe minor 's worldwide what how...     new york
# 10                talking myself wit fox just tho they    nashville
# 11   plus cleaning finna fckn mf make bout hump bda...      houston
# 12   anthony my finna ish uh tho nigga af med army ...      houston
# 13        rn lebron lee it\r\ndon’t your they your you     new york
# 14   bout kno cleaning all vid quality hello heisma...      houston
# 15   attend virginia hang ✨ gorgeous headed mad you...      houston
# 16   ion my gorgeous my carolina carolina they my m...      houston
# 17   dm my hump cloudy dropping rn bag texas done p...      houston
# 18   tx they finna carolina carolina af bf cloudy t...      houston
# 19   ion nov connect how cause va they they your yo...      houston
# 20      tx carolina wore ion shoutout cowboys ion love      houston
# 21   invite my gotta all shoutout against anymore i...      houston
# 22   kno my asf hang breathe eating ma carolina the...      houston
# 23   my make my da army bday florida carolina ish v...      houston
# 24   bout my ordered all bday eating my bout caroli...      houston
# 25   who my my my mf ion my succeed bday can they i...      houston
# 26   my florida birthday suddenly sick wit cant alu...      houston
# 27   dm my kindly ish awards couple bout decide bda...      houston
# 28   they ncaa follow my they carolina my houston b...      houston
# 29   plan my bday my tx my my carolina they never t...      houston
# ..                                                 ...          ...
# 100          pairing out ontario manor ontario vanilla      toronto
# 101  ln someone how going you how wouldnt how kiss ...      toronto
# 102        never going your it never terminal graffiti     new york
# 103  celebrated street\r\nb/w harry feel how va pol...     new york
# 104  terminal going how trump harry feel cherry f. ...     new york
# 105  how it you up going your good studios ontario ...     new york
# 106  never it how how never out unhealthy banana mu...     new york
# 107  react mueller never terminal going how right e...     new york
# 108          terminal going going toronto, never going     new york
# 109                  going it how it going how how how     new york
# 110                          reason feel ya — n min lo     new york
# 111                    stop honor file nov. - like you      houston
# 112  hug right how ontario wilder never climate man...     new york
# 113  pairing your it you colts about target going j...      seattle
# 114  grab have glad b honor at your just your my th...    charlotte
# 115  nothing it it feel good ive strawberry snapcha...     new york
# 116  how never out scene s ny fox near f. just it s...     new york
# 117  l they my your with your i recognition whole s...    charlotte
# 118  prepare venice ontario colts treatment thick m...     new york
# 119  your have they couple shoutout flower let flex...      houston
# 120                                                         houston
# 121  steph my ish ish gon they tx colts ish georgia...      houston
# 122  doors cleaning finna done thick straight flori...      houston
# 123  mf eating finna are williams they em spring ar...      houston
# 124  your they they how rly click team gorgeous cel...      houston
# 125  wrap all finna my ive luck gotta they they you...      houston
# 126  niggas houston mf mf metro couple they have th...      houston
# 127  oak carolina thick carolina tuesday apply my t...      houston
# 128  fair and finest out catching these when love t...     new york
# 129  wit mf chill all my they they you your they th...      houston
#
#     Trans BLEU                                      Retranslation  \
# 0            0                             my my mf people , army
# 1            0        they are we keep have showcase they my they
# 2     0.238255  we they never how it they just your your they ...
# 3            0  tx my schedule mf catching against be your you...
# 4            0  you they they my they aim they willing just pu...
# 5            0              so never become died wore white buena
# 6            0   bout florida few amen ky shoutout they my gladly
# 7            0                            they my my it til south
# 8            0  up while james others snapchat incredibly thro...
# 9            0  attended honored angels to tasty these from fy...
# 10           0                  your how how never it vanilla fox
# 11           0  nothing how going never invaded strawberry pal...
# 12    0.165528  it we going (i-87) harry never f. ny right you...
# 13           0    never going how how ontario failed cloudy every
# 14    0.199439  they they i right snap go strawberry players a...
# 15           0  wilder it how how need biz harry f. ontario to...
# 16           0  recognition to breakfast we milk to on are lat...
# 17     0.22605  saved we how giant rub can museum how s have m...
# 18           0  how ontario disneyland theft feel someone disn...
# 19           0  never it how banana harry spencer civilians to...
# 20           0                  jews had are black of due eb load
# 21           0  my officially cheers thick latin illegal media...
# 22           0  dedicated named bitch hella had bday got incre...
# 23    0.209775  brought fruit potato toy potter cats potter md...
# 24    0.233115  she elves she have they bday them carolina adv...
# 25           0  mcconnell alert x must are know per nov perfor...
# 26           0  to it how how unhealthy prayed boomerang targe...
# 27           0  cheers street\r\nb/w discovered surprise cheer...
# 28           0  fr they just they people pussy shower need bea...
# 29           0  how can founders shoutout per saudi our busy e...
# ..         ...                                                ...
# 100          0                you on they advertise these allowed
# 101    0.20746  nancy nathan tour barking condition helper nee...
# 102          0                     they my gotta food broke my ma
# 103          0  shoutout med # bitches heisman anthony shoutou...
# 104   0.209775  jews qualified quotes believes they finest all...
# 105          0  have cook bitch tummy tomorrow order vote usel...
# 106    0.16101  toy colts how deleted routes helper las never ...
# 107          0  laughing draw shared laughing out demand lunch...
# 108          0                    voice plan bday til my shoutout
# 109          0     they plan right other blessed program my texas
# 110          0                 never how it never never how never
# 111          0        good your how how harry strawberry terminal
# 112          0  invaded going right good right how need your i...
# 113   0.160419  how how else feel it it need it feel you it it...
# 114          0  bradford it going how it how terminal never on...
# 115   0.184293  hp right ontario ontario va how feel it how ne...
# 116   0.184293  logan going it never it just just your you you...
# 117          0  v loss next my liberty hugh your your your you...
# 118          0  nov your your how going it going how how how h...
# 119          0  liberty museum disneyland how how how mueller ...
# 120          0
# 121          0  nathan going never someone feel feel just how ...
# 122          0  routes how going (📍 going how just never never...
# 123   0.180685  they you they we respect nov nov can my bday i...
# 124   0.190085  pussy security how are they just out they pref...
# 125          0  your know to mega bday congrats not schedule b...
# 126   0.166237  going it going how need has slightly advertise...
# 127   0.168472  how how going never tour cared terminal going ...
# 128          0  kno not gon vs. treat my anthony snap homie cr...
# 129          0  they my it nah phone can risk got dream cook c...
#
#     Retrans Region Retrans BLEU
# 0          houston            0
# 1          houston            0
# 2        charlotte     0.168472
# 3          houston     0.180685
# 4         new york     0.203225
# 5          houston            0
# 6          houston            0
# 7          houston            0
# 8         new york            0
# 9         new york            0
# 10        new york            0
# 11        new york     0.170063
# 12         toronto     0.217848
# 13        new york            0
# 14        new york     0.167708
# 15        new york            0
# 16        new york     0.169257
# 17        new york     0.210364
# 18        new york            0
# 19        new york            0
# 20         houston            0
# 21         houston            0
# 22         houston            0
# 23        new york     0.176399
# 24         houston     0.196026
# 25        new york            0
# 26        new york            0
# 27        new york            0
# 28         houston            0
# 29         houston            0
# ..             ...          ...
# 100        houston            0
# 101       new york            0
# 102        houston            0
# 103        houston            0
# 104       new york            0
# 105        houston     0.214872
# 106       new york      0.16101
# 107       new york     0.181848
# 108        houston            0
# 109        houston            0
# 110        toronto            0
# 111       new york            0
# 112        toronto            0
# 113        toronto     0.211124
# 114        toronto            0
# 115        toronto     0.184293
# 116      charlotte     0.184293
# 117       new york            0
# 118       new york     0.186905
# 119        toronto            0
# 120        houston            0
# 121        toronto     0.192591
# 122        toronto            0
# 123       new york     0.214872
# 124        houston     0.159842
# 125        houston            0
# 126        toronto     0.166237
# 127        toronto            0
# 128        houston            0
# 129        houston            0
#
# [130 rows x 10 columns]

# %%
df_scores.loc[df_scores['Target'] == 'houston']
# Out:
#         Source   Target Decile  \
# 20  cincinnati  houston      0
# 21  cincinnati  houston      1
# 22  cincinnati  houston      2
# 23  cincinnati  houston      3
# 24  cincinnati  houston      4
# 25  cincinnati  houston      5
# 26  cincinnati  houston      6
# 27  cincinnati  houston      7
# 28  cincinnati  houston      8
# 29  cincinnati  houston      9
#
#                                              Original  \
# 20              made this for &amp; hope they like it
# 21  being than you are literally at when it comes ...
# 22    one taught me love taught me one taught me pain
# 23  i’m so thankful to have parents who are the gr...
# 24  does anyone else’s heart drop at the sound of ...
# 25  if only notre dame could figure out how to a c...
# 26  may we all experience this joy at the end. is ...
# 27  one could argue that no one brings more to a a...
# 28  interested in a #job in #indianapolis, in? thi...
# 29  big game. big implications. i'm picking #4 mic...
#
#                                           Translation Trans Region Trans BLEU  \
# 20     tx carolina wore ion shoutout cowboys ion love      houston          0
# 21  invite my gotta all shoutout against anymore i...      houston          0
# 22  kno my asf hang breathe eating ma carolina the...      houston          0
# 23  my make my da army bday florida carolina ish v...      houston   0.209775
# 24  bout my ordered all bday eating my bout caroli...      houston   0.233115
# 25  who my my my mf ion my succeed bday can they i...      houston          0
# 26  my florida birthday suddenly sick wit cant alu...      houston          0
# 27  dm my kindly ish awards couple bout decide bda...      houston          0
# 28  they ncaa follow my they carolina my houston b...      houston          0
# 29  plan my bday my tx my my carolina they never t...      houston          0
#
#                                         Retranslation Retrans Region  \
# 20                  jews had are black of due eb load        houston
# 21  my officially cheers thick latin illegal media...        houston
# 22  dedicated named bitch hella had bday got incre...        houston
# 23  brought fruit potato toy potter cats potter md...       new york
# 24  she elves she have they bday them carolina adv...        houston
# 25  mcconnell alert x must are know per nov perfor...       new york
# 26  to it how how unhealthy prayed boomerang targe...       new york
# 27  cheers street\r\nb/w discovered surprise cheer...       new york
# 28  fr they just they people pussy shower need bea...        houston
# 29  how can founders shoutout per saudi our busy e...        houston
#
#    Retrans BLEU
# 20            0
# 21            0
# 22            0
# 23     0.176399
# 24     0.196026
# 25            0
# 26            0
# 27            0
# 28            0
# 29            0

# %%
# printing the original input and the translated output
for i in range(len(input_text_to_translator)):
    print(get_text(input_text_to_translator)[i], '->', get_text(translated_output)[i])

# %%
# printing the output of the final dense layer for the input and the translated output after gradient ascent
# get id's of words with maximum probability
dense_output = get_dense_output([input_text_to_translator])[0]
text_output = np.argmax(dense_output, axis=-1)
for i in range(len(input_text_to_translator)):
    print(get_text(text_output)[i], '->', get_text(translated_output)[i])

# %%
for i in range(len(input_text_to_translator)):
    print(get_text(text_output)[i], '->', get_text(retranslated_output)[i])
